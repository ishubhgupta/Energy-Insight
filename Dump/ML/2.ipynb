# %%
import pandas as pd

df = pd.read_csv("ENB2012_data.csv")
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df['X9'] = (df['X3']/4)/df['X5']

df['X10'] = 2 * (df['X5'] + df['X9'])

# %% [markdown]
# Specifically:
# X1 Relative Compactness
# X2 Surface Area
# X3 Wall Area
# X4 Roof Area
# X5 Overall Height
# X6 Orientation
# X7 Glazing Area
# X8 Glazing Area Distribution
# y1 Heating Load
# y2 Cooling Load

# %%
df.head(40)
# Out:
#       X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2      X9    X10
# 0   0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33  10.500  35.00
# 1   0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33  10.500  35.00
# 2   0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33  10.500  35.00
# 3   0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33  10.500  35.00
# 4   0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28  11.375  36.75
# 5   0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.46  25.38  11.375  36.75
# 6   0.90  563.5  318.5  122.50  7.0   4  0.0   0  20.71  25.16  11.375  36.75
# 7   0.90  563.5  318.5  122.50  7.0   5  0.0   0  19.68  29.60  11.375  36.75
# 8   0.86  588.0  294.0  147.00  7.0   2  0.0   0  19.50  27.30  10.500  35.00
# 9   0.86  588.0  294.0  147.00  7.0   3  0.0   0  19.95  21.97  10.500  35.00
# 10  0.86  588.0  294.0  147.00  7.0   4  0.0   0  19.34  23.49  10.500  35.00
# ...

# %%
df['X6'].unique()
# Out:
# array([2, 3, 4, 5], dtype=int64)

# %%
#  Correlation matrix
correlation_matrix = df.corr()

# Correlation with the target variable
target_correlation = correlation_matrix['Y1']

# Print correlations
print(target_correlation)#
# Out:
# X1     0.622272
# X2    -0.658120
# X3     0.455671
# X4    -0.861828
# X5     0.889431
# X6    -0.002587
# X7     0.269841
# X8     0.087368
# Y1     1.000000
# Y2     0.975862
# X9    -0.730433
# X10   -0.619168
# Name: Y1, dtype: float64

# %%
#  Correlation matrix
correlation_matrix = df.corr()

# Correlation with the target variable
target_correlation = correlation_matrix['Y2']

# Print correlations
print(target_correlation)#
# Out:
# X1     0.634339
# X2    -0.672999
# X3     0.427117
# X4    -0.862547
# X5     0.895785
# X6     0.014290
# X7     0.207505
# X8     0.050525
# Y1     0.975862
# Y2     1.000000
# X9    -0.749008
# X10   -0.641953
# Name: Y2, dtype: float64

# %%
X = df.drop(columns=['Y1','Y2'])
y1 = df['Y1']
y2 = df['Y2']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y1, test_size = 0.2, random_state = 42)

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import root_mean_squared_error


clf1 = LGBMRegressor().fit(X_train, y_train)
y_pred = clf1.predict(X_test)

root_mean_squared_error(y_test, y_pred)
# Out:
# 0.4784990984162244

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y2, test_size = 0.2, random_state = 42)

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import root_mean_squared_error


clf2 = LGBMRegressor().fit(X_train, y_train)
y_pred = clf2.predict(X_test)

root_mean_squared_error(y_test, y_pred)
# Out:
# 1.1059710664467008

# %%
import matplotlib.pyplot as plt

# Scatter plot of actual vs predicted values
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Scatter Plot of Actual vs Predicted Values')
plt.show()

# %%
import seaborn as sns

# Distribution plot
sns.kdeplot(y_test, label='Actual', shade=True)
sns.kdeplot(y_pred, label='Predicted', shade=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Distribution of Actual vs Predicted Values')
plt.legend()
plt.show()
# Out:
# C:\Users\MB511WS\AppData\Local\Temp\ipykernel_11828\3250359107.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_test, label='Actual', shade=True)
# c:\Users\MB511WS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\MB511WS\AppData\Local\Temp\ipykernel_11828\3250359107.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_pred, label='Predicted', shade=True)
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

inp = [[0.82 , 612.50 , 318.50 , 147.00 , 3.50 ,  4 , 0.00 ,  0 , 11.375, 36.75]]

pred_heat_load = clf1.predict(inp)

print(pred_heat_load[0])
# Out:
# 15.745100000000019

# %%
import warnings
warnings.filterwarnings("ignore")

inp = [[0.82 , 612.50 , 318.50 , 147.00 , 3.50 ,  4 , 0.00 ,  0 , 11.375, 36.75]]

pred_cool_load = clf2.predict(inp)

print(pred_cool_load[0])
# Out:
# 17.942200000000028
